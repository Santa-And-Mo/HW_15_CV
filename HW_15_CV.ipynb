# %% [markdown]
# # HOMEWORK 15
#
# In this homework we will be working with the Fashion MNIST dataset. You will be given a classifier which suffers from considerable overfitting. Your objective will be to employ regularization techniques to mitigate the overfitting problem.
#
# Let's start with the usual imports.

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, Input, MaxPooling2D, BatchNormalization
from tensorflow.keras import Model
from time import time

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# Set the seeds for reproducibility
from numpy.random import seed
from tensorflow.random import set_seed
seed_value = 1234578790
seed(seed_value)
set_seed(seed_value)

# %% [markdown]
# ### Dataset
#
# The MNIST fashgion dataset [link](https://github.com/zalandoresearch/fashion-mnist) was build by Zalando Reasearch tem consists of monochrome images of different type of clothing, namely:
# * 0	T-shirt/top
# * 1	Trouser
# * 2	Pullover
# * 3	Dress
# * 4	Coat
# * 5	Sandal
# * 6	Shirt
# * 7	Sneaker
# * 8	Bag
# * 9	Ankle boot
#
# It is also one of the Keras built-in datasets. Let's load the images and quickly inspect it.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Dataset params
num_classes = 10
size = x_train.shape[1]

print('Train set:   ', len(y_train), 'samples')
print('Test set:    ', len(y_test), 'samples')
print('Sample dims: ', x_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Train set:    60000 samples
# Test set:     10000 samples
# Sample dims:  (60000, 28, 28)

# %% [markdown]
# Let's visualise some random samples.

# %%
cnt = 1
for r in range(3):
    for c in range(6):
        idx = np.random.randint(len(x_train))
        plt.subplot(3,6,cnt)
        plt.imshow(x_train[idx, ...], cmap='gray')
        plt.title(y_train[idx])
        cnt = cnt + 1

# %% [markdown]
# ### Building the Classifier
#
# We are now going to build the baseline classifier that you will use throughout this homework.

# %%
# Data normalization
x_train = x_train/255
x_test = x_test/255

# %%
inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,213,002 (12.26 MB)
#  Trainable params: 3,213,002 (12.26 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 50
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 88s 92ms/step - accuracy: 0.8653 - loss: 0.3833 - val_accuracy: 0.8820 - val_loss: 0.3244
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 141s 91ms/step - accuracy: 0.9074 - loss: 0.2589 - val_accuracy: 0.8890 - val_loss: 0.3098
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 89s 95ms/step - accuracy: 0.9222 - loss: 0.2159 - val_accuracy: 0.8899 - val_loss: 0.3098
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 88s 93ms/step - accuracy: 0.9338 - loss: 0.1858 - val_accuracy: 0.8945 - val_loss: 0.3204
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 139s 91ms/step - accuracy: 0.9428 - loss: 0.1617 - val_accuracy: 0.8952 - val_loss: 0.3377
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 143s 92ms/step - accuracy: 0.9499 - loss: 0.1423 - val_accuracy: 0.8960 - val_loss: 0.3506
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 87s 93ms/step - accuracy: 0.9564 - loss: 0.1249 - val_accuracy: 0.8926 - val_loss: 0.3895
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 85s 91ms/step - accuracy: 0.9595 - loss: 0.1134 - val_accuracy: 0.8953 - val_loss: 0.4047
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 140s 89ms/step - accuracy: 0.9649 - loss: 0.1013 - val_accuracy: 0.8938 - val_loss: 0.4486
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 142s 89ms/step - accuracy: 0.9682 - loss: 0.0913 - val_accuracy: 0.8919 - val_loss: 0.4776
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 90s 96ms/step - accuracy: 0.9718 - loss: 0.0797 - val_accuracy: 0.8816 - val_loss: 0.5803
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 136s 90ms/step - accuracy: 0.9741 - loss: 0.0741 - val_accuracy: 0.8817 - val_loss: 0.6176
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 85s 91ms/step - accuracy: 0.9756 - loss: 0.0705 - val_accuracy: 0.8792 - val_loss: 0.6442
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 89ms/step - accuracy: 0.9757 - loss: 0.0670 - val_accuracy: 0.8800 - val_loss: 0.6609
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 89ms/step - accuracy: 0.9792 - loss: 0.0584 - val_accuracy: 0.8852 - val_loss: 0.6542
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 141s 88ms/step - accuracy: 0.9795 - loss: 0.0555 - val_accuracy: 0.8836 - val_loss: 0.7045
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 88ms/step - accuracy: 0.9821 - loss: 0.0502 - val_accuracy: 0.8844 - val_loss: 0.7180
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 88ms/step - accuracy: 0.9824 - loss: 0.0488 - val_accuracy: 0.8822 - val_loss: 0.7815
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 89ms/step - accuracy: 0.9832 - loss: 0.0469 - val_accuracy: 0.8776 - val_loss: 0.8432
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 141s 88ms/step - accuracy: 0.9840 - loss: 0.0444 - val_accuracy: 0.8760 - val_loss: 0.8810
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 89ms/step - accuracy: 0.9856 - loss: 0.0394 - val_accuracy: 0.8691 - val_loss: 0.9733
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 88ms/step - accuracy: 0.9846 - loss: 0.0418 - val_accuracy: 0.8768 - val_loss: 0.9182
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 89ms/step - accuracy: 0.9849 - loss: 0.0413 - val_accuracy: 0.8784 - val_loss: 0.9327
# Epoch 24/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 143s 90ms/step - accuracy: 0.9883 - loss: 0.0320 - val_accuracy: 0.8812 - val_loss: 0.9924
# Epoch 25/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 89ms/step - accuracy: 0.9868 - loss: 0.0354 - val_accuracy: 0.8771 - val_loss: 1.0469
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 88ms/step - accuracy: 0.9871 - loss: 0.0370 - val_accuracy: 0.8759 - val_loss: 1.0183
# Epoch 27/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 144s 90ms/step - accuracy: 0.9876 - loss: 0.0331 - val_accuracy: 0.8799 - val_loss: 1.0415
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 89ms/step - accuracy: 0.9885 - loss: 0.0321 - val_accuracy: 0.8835 - val_loss: 1.0465
# Epoch 29/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 88ms/step - accuracy: 0.9887 - loss: 0.0322 - val_accuracy: 0.8760 - val_loss: 1.0470
# Epoch 30/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 86s 91ms/step - accuracy: 0.9900 - loss: 0.0272 - val_accuracy: 0.8823 - val_loss: 1.0279
# Epoch 31/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 140s 90ms/step - accuracy: 0.9899 - loss: 0.0280 - val_accuracy: 0.8862 - val_loss: 1.0534
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 89ms/step - accuracy: 0.9893 - loss: 0.0287 - val_accuracy: 0.8838 - val_loss: 1.0602
# Epoch 33/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 89ms/step - accuracy: 0.9898 - loss: 0.0286 - val_accuracy: 0.8843 - val_loss: 1.0563
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 141s 88ms/step - accuracy: 0.9909 - loss: 0.0250 - val_accuracy: 0.8818 - val_loss: 1.0934
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 89ms/step - accuracy: 0.9910 - loss: 0.0247 - val_accuracy: 0.8869 - val_loss: 1.1286
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 89ms/step - accuracy: 0.9902 - loss: 0.0271 - val_accuracy: 0.8779 - val_loss: 1.2027
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 88ms/step - accuracy: 0.9916 - loss: 0.0235 - val_accuracy: 0.8829 - val_loss: 1.1658
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 142s 88ms/step - accuracy: 0.9915 - loss: 0.0240 - val_accuracy: 0.8803 - val_loss: 1.1967
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.9909 - loss: 0.0258 - val_accuracy: 0.8795 - val_loss: 1.1940
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 88ms/step - accuracy: 0.9920 - loss: 0.0238 - val_accuracy: 0.8775 - val_loss: 1.1583
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 88ms/step - accuracy: 0.9922 - loss: 0.0227 - val_accuracy: 0.8822 - val_loss: 1.1847
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 88ms/step - accuracy: 0.9915 - loss: 0.0228 - val_accuracy: 0.8822 - val_loss: 1.1877
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 88ms/step - accuracy: 0.9934 - loss: 0.0189 - val_accuracy: 0.8811 - val_loss: 1.2170
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 143s 89ms/step - accuracy: 0.9927 - loss: 0.0198 - val_accuracy: 0.8768 - val_loss: 1.2675
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 87ms/step - accuracy: 0.9925 - loss: 0.0199 - val_accuracy: 0.8823 - val_loss: 1.2605
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 88ms/step - accuracy: 0.9923 - loss: 0.0229 - val_accuracy: 0.8777 - val_loss: 1.3135
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 88ms/step - accuracy: 0.9926 - loss: 0.0207 - val_accuracy: 0.8826 - val_loss: 1.2803
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 143s 89ms/step - accuracy: 0.9933 - loss: 0.0192 - val_accuracy: 0.8848 - val_loss: 1.2992
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 144s 91ms/step - accuracy: 0.9930 - loss: 0.0194 - val_accuracy: 0.8782 - val_loss: 1.3478
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 85s 91ms/step - accuracy: 0.9939 - loss: 0.0179 - val_accuracy: 0.8795 - val_loss: 1.3447

# %%
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])

    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])

plot_history(history)
# Out:
# Train Acc      0.9939333200454712
# Validation Acc 0.8794999718666077

# %% [markdown]
# As you can see, the classifier suffers from massive overfitting. The validation accuracy is around 88% while the training accuracy is close to 1.

# %% [markdown]
# ### Combat the Overfitting!
#
# Now it is your turn. Use the classifier as a baseline, include some regularization techniques and try to improve the classification performance. You can try any techniques you might see fit, e.g.,
# * Dropout
# * Batch normalization
# * Weight regularization
# * Data augmentation
# * Early stopping
# * Pooling
# * Reducing the number of parameters (the size of the network)
# * ...
#
# There are to objective you shall fulfill in order to successfully complete this homework:
# * The validation accuracy shall be above 91%
# * Your network (with all the regularizations applied) shall **not** be larger than the baseline

# %%
# Modify the baseline classifier in order to reduce the overfitting and make the performance more robust

from tensorflow.keras.regularizers import l2

inputs = Input(shape=(28, 28, 1))

net = Conv2D(32, (3, 3), padding='same')(inputs)
net = BatchNormalization()(net)
net = tf.keras.activations.relu(net)
net = MaxPooling2D()(net)

net = Conv2D(64, (3, 3), padding='same')(net)
net = BatchNormalization()(net)
net = tf.keras.activations.relu(net)
net = MaxPooling2D()(net)

net = Flatten()(net)

net = Dense(64, kernel_regularizer=l2(0.001))(net)
net = tf.keras.activations.relu(net)
net = Dropout(0.5)(net)

outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 28, 28, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 28, 28, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 14, 14, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │       200,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 220,618 (861.79 KB)
#  Trainable params: 220,426 (861.04 KB)
#  Non-trainable params: 192 (768.00 B)

# %%
# Train the network
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    x_train, y_train,
    epochs=30,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/30
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 96s 125ms/step - accuracy: 0.6668 - loss: 0.9868 - val_accuracy: 0.8404 - val_loss: 0.5298
# Epoch 2/30
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 92s 122ms/step - accuracy: 0.7437 - loss: 0.7331 - val_accuracy: 0.8496 - val_loss: 0.4684
# Epoch 3/30
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 91s 122ms/step - accuracy: 0.7736 - loss: 0.6520 - val_accuracy: 0.8795 - val_loss: 0.4080
# Epoch 4/30
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 142s 122ms/step - accuracy: 0.7902 - loss: 0.6115 - val_accuracy: 0.8870 - val_loss: 0.3814
# Epoch 5/30
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 141s 120ms/step - accuracy: 0.8018 - loss: 0.5800 - val_accuracy: 0.8928 - val_loss: 0.3706
# Epoch 6/30
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 89s 119ms/step - accuracy: 0.8164 - loss: 0.5473 - val_accuracy: 0.8928 - val_loss: 0.3730
# Epoch 7/30
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 142s 119ms/step - accuracy: 0.8225 - loss: 0.5334 - val_accuracy: 0.8965 - val_loss: 0.3640
# Epoch 8/30
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 89s 118ms/step - accuracy: 0.8272 - loss: 0.5233 - val_accuracy: 0.9028 - val_loss: 0.3482
# Epoch 9/30
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 90s 120ms/step - accuracy: 0.8290 - loss: 0.5163 - val_accuracy: 0.8993 - val_loss: 0.3481
# Epoch 10/30
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 90s 120ms/step - accuracy: 0.8306 - loss: 0.5089 - val_accuracy: 0.9014 - val_loss: 0.3501
# Epoch 11/30
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 141s 119ms/step - accuracy: 0.8367 - loss: 0.4974 - val_accuracy: 0.9023 - val_loss: 0.3501
# Epoch 12/30
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 88s 118ms/step - accuracy: 0.8362 - loss: 0.4956 - val_accuracy: 0.9034 - val_loss: 0.3341
# Epoch 13/30
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 143s 119ms/step - accuracy: 0.8431 - loss: 0.4842 - val_accuracy: 0.9009 - val_loss: 0.3481
# Epoch 14/30
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 87s 117ms/step - accuracy: 0.8474 - loss: 0.4780 - val_accuracy: 0.9047 - val_loss: 0.3370
# Epoch 15/30
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 143s 118ms/step - accuracy: 0.8485 - loss: 0.4763 - val_accuracy: 0.9114 - val_loss: 0.3288
# Epoch 16/30
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 88s 117ms/step - accuracy: 0.8499 - loss: 0.4708 - val_accuracy: 0.9081 - val_loss: 0.3319
# Epoch 17/30
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 88s 117ms/step - accuracy: 0.8537 - loss: 0.4624 - val_accuracy: 0.9093 - val_loss: 0.3317
# Epoch 18/30
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 145s 121ms/step - accuracy: 0.8568 - loss: 0.4571 - val_accuracy: 0.9087 - val_loss: 0.3305

# %%
# Show the results
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test loss:", test_loss)
print("Test accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9053 - loss: 0.3446
# Test loss: 0.344583123922348
# Test accuracy: 0.9053000211715698

# %%
plt.figure(figsize=(12,5))

# Accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.legend()
plt.title('Accuracy')

# Loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.title('Loss')

plt.show()

# %% [markdown]
# ### Questions
#
# * What have you done in order to improve the performance?
# * Добавил MaxPooling для уменьшения количества параметров
# Использовал Batch Normalization для стабильного обучения
# Применил Dropout (0.5) для уменьшения переобучения
# Добавил L2-регуляризацию
# Использовал EarlyStopping
# Это помогло снизить overfitting и получить точность почти 91%.
#
# * Have you tried configurations that did not work out?
# * Да, Базовая модель без pooling сильно переобучалась
# Один Dropout без уменьшения модели не помог
# Слишком большой Dropout → недообучение
# Более сложная модель → хуже результат и больше overfitting
